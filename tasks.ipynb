# %% [markdown]
# # Principles of Data Analytics

# %% [markdown]
# ## TASKS

# %% [markdown]
# In this repository, you would find the codes used to complete different tasks for ATU - Principles of Data Analytics

# %% [markdown]
# ## TASK 1

# %% [markdown]
# Importing a DataSet from a website.

# %%
# Import iris
import pandas as pd
from sklearn.datasets import load_iris
import numpy as np

# %%
# Load the iris dataset.
X = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
# Load the dataset.
iris = load_iris()

# %% [markdown]
# What I understand from load_iris() is a function that load all the iris dataset to use it in future opportunities.

# %% [markdown]
# ## TASK 2

# %% [markdown]
# Print the shape of the DataSet and the last 5 rows and their feature names.

# %%
# Display the first 5 rows of the data
print("First 5 rows of the data (features):")
print(X[:5])
# Out:
# First 5 rows of the data (features):
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Display the last 5 rows of the data
print("Last 5 rows of the data (features):")
print(X[-5:])
# Out:
# Last 5 rows of the data (features):
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# Display feature names
print("Feature names:", iris.feature_names)
# Out:
# Feature names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
# Display target names (target classes)
print("Target classes:", iris.target_names)
# Out:
# Target classes: ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# ## TASK 3

# %% [markdown]
# Calculate and display for each feature in dataset:
#
# mean
#
# minimum
#
# maximum
#
# standard deviation
#
# median

# %%
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# %% [markdown]
# ### Mean

# %%
# Calculates the mean of a numbers of the feature.
import statistics

means = df.mean()

print("Mean of each Feature is:\n", means)
# Out:
# Mean of each Feature is:
#  sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64

# %% [markdown]
# ### Min

# %%
# Print the minimum number of a list.

minimum = df.min()
print("The min value of each Feature is\n", minimum)
# Out:
# The min value of each Feature is
#  sepal length (cm)    4.3
# sepal width (cm)     2.0
# petal length (cm)    1.0
# petal width (cm)     0.1
# dtype: float64

# %% [markdown]
# ### Maximum

# %%
# Print the maximum number of a list.

maximum = df.max()

print("The maximum value of each feature is:\n", maximum)
# Out:
# The maximum value of each feature is:
#  sepal length (cm)    7.9
# sepal width (cm)     4.4
# petal length (cm)    6.9
# petal width (cm)     2.5
# dtype: float64

# %% [markdown]
# ### Standard Deviation

# %%
# Calculates the Stand Deviation of a number´s list

standard = df.std()

print("The standar deviation of each feature is:\n",standard)
# Out:
# The standar deviation of each feature is:
#  sepal length (cm)    0.828066
# sepal width (cm)     0.435866
# petal length (cm)    1.765298
# petal width (cm)     0.762238
# dtype: float64

# %% [markdown]
# ### Median

# %%
# Calculate median of the features
medians = df.median()

print("Median of each feature:\n", medians)
# Out:
# Median of each feature:
#  sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# dtype: float64

# %% [markdown]
# ## TASK 4

# %% [markdown]
# Creating a histogram for each variable of Iris Data Set

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets
data = datasets.load_iris()

for i, feature in enumerate(df.columns):
    plt.figure(figsize=(10, 6))
    sns.histplot(df[feature], bins=20, color='skyblue') # Using "feature" to do the graphics with all the variables in the data set.
    plt.title(f'Histogram of {feature}')
    plt.xlabel(feature)
    plt.ylabel('frequency')

plt.show()

# %% [markdown]
# ## Task 5

# %% [markdown]
# Create a scatter plot from different features.

# %%
import pandas as pd
from sklearn.datasets import load_diabetes

# Load diabetes dataset
diabetes = load_diabetes()

# %%
diabetes.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
# Blood preassure.

bp = diabetes.data[3]

#Show
bp
# Out:
# array([-0.08906294, -0.04464164, -0.01159501, -0.03665608,  0.01219057,
#         0.02499059, -0.03603757,  0.03430886,  0.02268774, -0.00936191])

# %%
# Age.

age = diabetes.data[0]

# Show
age
# Out:
# array([ 0.03807591,  0.05068012,  0.06169621,  0.02187239, -0.0442235 ,
#        -0.03482076, -0.04340085, -0.00259226,  0.01990749, -0.01764613])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar el dataset desde una URL
url = "https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv"
df = pd.read_csv(url)

# Selección de variables
X = df[['BloodPressure', 'Age']]
y = df['Outcome']

# Gráfico
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X['BloodPressure'], y=X['Age'], hue=y, palette='coolwarm', style=y, markers=["o", "X"])

plt.title('Blood Pressure and Age')
plt.xlabel('Blood Pressure')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ## Task 6

# %% [markdown]
# Use numpy.polyfit to add a regression line to the scatter plot from Task 5.

# %%
X = df[['BloodPressure', 'Age']]
y = df['Outcome']

plt.figure(figsize=(10, 6))

sns.scatterplot(x=X['BloodPressure'], y=X['Age'], hue=y, palette='coolwarm', style=y, markers=["o", "X"])

# Regression Line 
slope, intercept = np.polyfit(X['BloodPressure'], X['Age'], 1)

# Creation of Line
regression_line = slope * X['BloodPressure'] + intercept


# Plot the regression line
plt.plot(X['BloodPressure'], regression_line, color='black', linestyle='--', label='Regression Line')

# Labels and title
plt.title('Blood Preassure and Age')
plt.xlabel('Blood Pressure')
plt.ylabel('Age')

plt.show()

# %% [markdown]
# ## Task 7

# %% [markdown]
# Box-plots of the petal lengths for each of the three classes.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset("iris")

# Box plot of petal lengths by species
plt.figure(figsize=(8, 6))
sns.boxplot(x="species", y="petal_length", data=iris)

# Labels and title
plt.title("Lengths by Iris Species")
plt.xlabel("Iris Species")
plt.ylabel("Petal Length (cm)")

# Display the plot
plt.show()

# %% [markdown]
# ## Task 8

# %% [markdown]
# Calculate the correlation coefficients between the features.
# Display the results as a heatmap using matplotlib.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the Iris dataset
iris = sns.load_dataset("iris")

# Calculate the correlation matrix
corr_matrix = iris.drop("species", axis=1).corr()

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", cbar=True, linewidths=0.5)

# Tittle and Show
plt.title("Correlation Heatmap of Iris Dataset Features")
plt.show()

# %% [markdown]
# ## Task 9

# %% [markdown]
# Calculate the coefficient of determination R2 for task 5.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Fit linear regression model
model = LinearRegression()
model.fit(X, y)

# Predict using the model
y_pred = model.predict(X)

# Calculate R^2
r2 = r2_score(y, y_pred)
print(f"R² (Coefficient of Determination): {r2:.4f}")
# Out:
# R² (Coefficient of Determination): 0.0569

# %% [markdown]
# Recreating plot of task 6 with R2

# %%
# Load dataset
url = "https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv"
df = pd.read_csv(url)

# Features and target
X = df[['BloodPressure', 'Age']]
y = df['Outcome']

# Fit a linear regression model using BloodPressure to predict Age
x_vals = X['BloodPressure'].values.reshape(-1, 1)
y_vals = X['Age'].values

model = LinearRegression()
model.fit(x_vals, y_vals)
age_pred = model.predict(x_vals)

# Calculate R² score
r2 = r2_score(y_vals, age_pred)

# Create the plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X['BloodPressure'], y=X['Age'], hue=y, palette='coolwarm', style=y, markers=["o", "X"])

# Plot regression line
plt.plot(X['BloodPressure'], age_pred, color='black', linestyle='--', label='Regression Line')

# Add R² annotation
plt.text(x=40, y=80, s=f'$R^2$: {r2:.4f}', fontsize=12, bbox=dict(facecolor='white', alpha=0.6))

# Titles and labels
plt.title('Blood Pressure and Age with Regression Line and $R^2$')
plt.xlabel('Blood Pressure')
plt.ylabel('Age')
plt.legend()
plt.show()

# %% [markdown]
# ## Task 10

# %% [markdown]
# Use seaborn to create a pairplot of the data set.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes

# Load the dataset
diabetes = load_diabetes()

# Create a DataFrame
df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
df['target'] = diabetes.target  # add the target column

# Select a few features to plot
features_to_plot = ['bmi', 'bp', 's1', 's5', 'target']

# Pairplot using seaborn
sns.pairplot(df[features_to_plot], diag_kind="kde")
plt.suptitle("Pairplot of Diabetes Dataset", y=1.02)
plt.show()

# %% [markdown]
# ### Explain, in your own words, what the pairplot depicts.
#
#
# From my perspective, a pairplot is a type of graphics visualization to compares multiple variables of a dataset.

# %% [markdown]
# ## END
