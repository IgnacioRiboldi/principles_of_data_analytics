# %% [markdown]
# # Principles of Data Analytics

# %% [markdown]
# ## TASKS

# %% [markdown]
# In this repository, you would find the codes used to complete different tasks for ATU - Principles of Data Analytics

# %% [markdown]
# ## TASK 1

# %% [markdown]
# Importing a DataSet from a website.

# %%
# Import iris
import pandas as pd
from sklearn.datasets import load_iris
import numpy as np

# %%
# Load the iris dataset.
X = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
# Load the dataset.
iris = load_iris()

# %% [markdown]
# What I understand from load_iris() is a function that load all the iris dataset to use it in future opportunities.

# %% [markdown]
# # TASK 2

# %% [markdown]
# Print the shape of the DataSet and the last 5 rows and their feature names.

# %%
# Display the first 5 rows of the data
print("First 5 rows of the data (features):")
print(X[:5])
# Out:
# First 5 rows of the data (features):
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Display the last 5 rows of the data
print("Last 5 rows of the data (features):")
print(X[-5:])
# Out:
# Last 5 rows of the data (features):
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# Display feature names
print("Feature names:", iris.feature_names)
# Out:
# Feature names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
# Display target names (target classes)
print("Target classes:", iris.target_names)
# Out:
# Target classes: ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# ## TASK 3

# %% [markdown]
# Calculate and display for each feature in dataset:
#
# mean
#
# minimum
#
# maximum
#
# standard deviation
#
# median

# %%
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# %% [markdown]
# # Mean

# %%
# Calculates the mean of a numbers of the feature.
import statistics

means = df.mean()

print("Mean of each Feature is:\n", means)
# Out:
# Mean of each Feature is:
#  sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64

# %% [markdown]
# # Min

# %%
# Print the minimum number of a list.

minimum = df.min()
print("The min value of each Feature is\n", minimum)
# Out:
# The min value of each Feature is
#  sepal length (cm)    4.3
# sepal width (cm)     2.0
# petal length (cm)    1.0
# petal width (cm)     0.1
# dtype: float64

# %% [markdown]
# # Maximum

# %%
# Print the maximum number of a list.

maximum = df.max()

print("The maximum value of each feature is:\n", maximum)
# Out:
# The maximum value of each feature is:
#  sepal length (cm)    7.9
# sepal width (cm)     4.4
# petal length (cm)    6.9
# petal width (cm)     2.5
# dtype: float64

# %% [markdown]
# # Standard Deviation

# %%
# Calculates the Stand Deviation of a number´s list

standard = df.std()

print("The standar deviation of each feature is:\n",standard)
# Out:
# The standar deviation of each feature is:
#  sepal length (cm)    0.828066
# sepal width (cm)     0.435866
# petal length (cm)    1.765298
# petal width (cm)     0.762238
# dtype: float64

# %% [markdown]
# # Median

# %%
# Calculate median of the features
medians = df.median()

print("Median of each feature:\n", medians)
# Out:
# Median of each feature:
#  sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# dtype: float64

# %% [markdown]
# # TASK 4

# %% [markdown]
# Creating a histograms for each feature.

# %%
import matplotlib.pyplot as plt

plt.hist(means, bins=len(means),edgecolor = 'black')

plt.title('Histogram of Mean Values')
plt.xlabel('Mean Value')
plt.ylabel('Frequency')
plt.xticks(ticks=range(len(means)), labels=means.index, rotation=45)
plt.show()

# %%
plt.hist(minimum, bins=len(minimum),edgecolor = 'black')

plt.title('Histogram of Minimum Values')
plt.xlabel('Minimum Value')
plt.ylabel('Frequency')
plt.xticks(ticks=range(len(minimum)), labels=minimum.index, rotation=45)

plt.show()

# %%
plt.hist(maximum, bins=len(maximum),edgecolor = 'black')

plt.title('Histogram of Maximum Values')
plt.xlabel('Maximum Value')
plt.ylabel('Frequency')
plt.xticks(ticks=range(len(maximum)), labels=maximum.index, rotation=45)

plt.show()

# %%
plt.hist(standard, bins=len(standard), edgecolor = 'black')

plt.title('Histogram of Standard Values')
plt.xlabel('Standard Value')
plt.ylabel('Frequency')
plt.xticks(ticks=range(len(standard)), labels=standard.index)

plt.show()

# %%
plt.hist(medians, bins=len(medians), edgecolor = 'black')

plt.title('Histogram of Median Values')
plt.xlabel('Median Value')
plt.ylabel('Frequency')
plt.xticks(ticks=range(len(medians)), labels=medians.index, rotation=45)

plt.show()

# %% [markdown]
# # Task 5

# %% [markdown]
# Create a scatter plot from different features.

# %%
# Load Diabetes Data Set
X = pd.read_csv('https://www4.stat.ncsu.edu/~boos/var.select/diabetes.tab.txt')

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes

# Load diabetes dataset
diabetes = load_diabetes()

# Get the first two features for the scatter plot
X = diabetes.data[:, :2]
y = diabetes.target

# Create the scatter plot
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Scatter Plot of First Two Features in the Diabetes Dataset')
plt.show()

# %% [markdown]
# ## END
